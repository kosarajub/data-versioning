# %% [markdown]
# <h1 style="padding-top: 25px;padding-bottom: 25px;text-align: left; padding-left: 10px; background-color: #DDDDDD;
#     color: black;"> <img style="float: left; padding-right: 10px;" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png" height="50px"> <a href='https://harvard-iacs.github.io/2023-AC215/' target='_blank'><strong><font color="#A41034">AC215: Productionizing AI (MLOps)</font></strong></a></h1>
#
# # **<font color="#A41034">Tutorial - Data Pipelines, Labeling, Versioning, Cloud Storage</font>**
#
# **Harvard University**<br/>
# **Fall 2025**<br/>
# **Instructor:**<br/>
# Pavlos Protopapas
#
# <hr style="height:2pt">

# %% [markdown]
# ## **<font color="#A41034">Tutorial Outline</font>**

# %% [markdown]
# ## **Learning Objectives**
#
# By the end of this notebook, you will be:
# * Familiar with data version from a DVC repo
#
#
# ## **Tutorial Content**
#
# In order to run this tutorial you should have completed [Data Labeling & Versioning](https://github.com/dlops-io/data-labeling) steps.
#
# - View data from a remote DVC repo
# - Retrieve data from a remote DVC repo
# - Retrieve a specifi data version from DVC

# %% [markdown]
# ## **<font color="#A41034">Setup Notebook</font>**

# %% [markdown]
# **Copy & setup Colab**

# %% [markdown]
# 1) Select "File" menu and pick "Save a copy in Drive"

# %% [markdown]
# **Installs**

# %%
#!pip install dvc dvc-gs

# %% [markdown]
# **Imports**

# %%
from traitlets import Unicode

import os
import cv2
import numpy as np
import pandas as pd

# Colab auth
from google.colab import auth
from google.cloud import storage
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 9
#       6 import pandas as pd
#       8 # Colab auth
# ----> 9 from google.colab import auth
#      10 from google.cloud import storage
#
# File /opt/anaconda3/envs/bkos/lib/python3.10/site-packages/google/colab/__init__.py:26
#      24 from google.colab import _tensorflow_magics
#      25 from google.colab import auth
# ---> 26 from google.colab import data_table
#      27 from google.colab import drive
#      28 from google.colab import files
#
# File /opt/anaconda3/envs/bkos/lib/python3.10/site-packages/google/colab/data_table.py:166
#     149       columns_and_types.append((column_type, str(header_formatters[i](column))))
#     151     return """
#     152       import "{gviz_url}";
#     153
#    (...)
#     162         columns=_json.dumps(columns_and_types),
#     163         num_rows_per_page=self._num_rows_per_page)
# --> 166 class _JavascriptModuleFormatter(_IPython.core.formatters.BaseFormatter):
#     167   format_type = _traitlets.Unicode(_JAVASCRIPT_MODULE_MIME_TYPE)
#     168   print_method = _traitlets.ObjectName('_repr_javascript_module_')
#
# File /opt/anaconda3/envs/bkos/lib/python3.10/site-packages/google/colab/data_table.py:167, in _JavascriptModuleFormatter()
#     166 class _JavascriptModuleFormatter(_IPython.core.formatters.BaseFormatter):
# --> 167   format_type = _traitlets.Unicode(_JAVASCRIPT_MODULE_MIME_TYPE)
#     168   print_method = _traitlets.ObjectName('_repr_javascript_module_')
#
# AttributeError: module 'IPython.utils.traitlets' has no attribute 'Unicode'

# %% [markdown]
# ## **<font color="#A41034">Authenticate</font>**
#
# Here we authenticate your Google account that has access to your GCS bucket

# %%
# This step is required for DVC in colab to access your Bucket
auth.authenticate_user()

# %% [markdown]
# ## **View Remote Data**
#
# To view a DVC repository, listing data files and directories tracked by DVC alongside the remaining Git repo contents.
#
# [dvc list reference](https://dvc.org/doc/command-reference/list)

# %%
# Replace github url with your url
# !dvc list -R https://github.com/kosarajub/data-versioning
# Out:
# .dvcignore
# .gitignore
# Dockerfile
# README.md
# cheese_dataset.dvc
# cheese_dataset/Image_1.jpg
# cheese_dataset/Image_2.jpg
# cheese_dataset/Image_3.jpg
# cheese_dataset/Image_4.jpg
# cheese_dataset/csm_Gruyere_Website_Header_Desktop_1920x1080px_Homepage_Curling_cdd2c6527c.jpg.webp
# docker-entrypoint.sh
# docker-shell.sh
# pyproject.toml
# uv.lock

# %% [markdown]
# ## **Retrieving Data**
#
# Once DVC-tracked data are stored remotely, they can be downloaded with dvc get when needed.
#
# [dvc get reference](https://dvc.org/doc/command-reference/get)

# %%
# !rm -rf cheese_dataset
# !dvc get https://github.com/dlops-io/data-versioning cheese_dataset --force --rev dataset_v21
# Out:
# Downloading cheese_dataset:   0% 0/5 [00:00<?, ?files/s{'info': ''}]
# cheese_dataset/Image_1.jpg:   0% 0.00/242k [00:00<?, ?B/s]
# cheese_dataset/Image_1.jpg:   0% 0.00/242k [00:00<?, ?B/s{'info': ''}]
# Downloading cheese_dataset:  20% 1/5 [00:00<00:00,  8.95files/s{'info': ''}]
#   0% 0.00/170k [00:00<?, ?B/s]
#   0% 0.00/170k [00:00<?, ?B/s{'info': ''}]
#
# cheese_dataset/Image_3.jpg:   0% 0.00/106k [00:00<?, ?B/s]
# cheese_dataset/Image_3.jpg:   0% 0.00/106k [00:00<?, ?B/s{'info': ''}]
#
# cheese_dataset/Image_2.jpg:   0% 0.00/109k [00:00<?, ?B/s]
# cheese_dataset/Image_2.jpg:   0% 0.00/109k [00:00<?, ?B/s{'info': ''}]
#
# cheese_dataset/Image_4.jpg:   0% 0.00/140k [00:00<?, ?B/s]
#
# cheese_dataset/Image_4.jpg:   0% 0.00/140k [00:00<?, ?B/s{'info': ''}]

# %%
# Check the dataset
print("Number of items:",len(os.listdir("cheese_dataset")))
# Out:
# Number of items: 5

# %% [markdown]
# ## **Retrieve a different data version**

# %%
# !rm -rf cheese_dataset
# !dvc get https://github.com/dlops-io/data-versioning cheese_dataset --force --quiet --rev dataset_v25

# %%
# Check the dataset
print("Number of items:",len(os.listdir("cheese_dataset")))
# Out:
# Number of items: 3
